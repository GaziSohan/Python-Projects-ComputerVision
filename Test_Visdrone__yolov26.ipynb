# %% [markdown]
# <a href="https://colab.research.google.com/github/GaziSohan/Python-Projects-ComputerVision/blob/main/Test_Visdrone__yolov26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolo26n.pt')
results = model.train(data='VisDrone.yaml', epochs=10, imgsz=640)
# Out:
# ...
# Ultralytics 8.4.61 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
